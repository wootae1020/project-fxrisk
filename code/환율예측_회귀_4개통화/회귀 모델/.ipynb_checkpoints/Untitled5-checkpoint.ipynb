# %%
pip install apache-airflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from airflow import DAG
from airflow.operators.python_operator import PythonOperator
from datetime import datetime, timedelta

# 주기 설정
default_args = {
    'owner': 'airflow',
    'start_date': datetime(2023, 1, 1),
    'retries': 1,
    'retry_delay': timedelta(minutes=5),
}

dag = DAG(
    'stock_price_model_training',
    default_args=default_args,
    schedule_interval='0 6 * * 1',  # 매주 월요일 오전 6시 실행
    catchup=False
)

def fetch_stock_data():
    # yfinance 등으로 주가 데이터 수집
    pass

def preprocess_data():
    # 결측치 처리, 정규화 등
    pass

def feature_engineering():
    # EMA, RSI, lag 생성 등
    pass

def train_model():
    # 기존 모델 학습 (LSTM, XGBoost 등)
    pass

def evaluate_model():
    # MAE, R2 등 평가
    pass

# 태스크 등록
t1 = PythonOperator(task_id='fetch_data', python_callable=fetch_stock_data, dag=dag)
t2 = PythonOperator(task_id='preprocess', python_callable=preprocess_data, dag=dag)
t3 = PythonOperator(task_id='feature_engineering', python_callable=feature_engineering, dag=dag)
t4 = PythonOperator(task_id='train_model', python_callable=train_model, dag=dag)
t5 = PythonOperator(task_id='evaluate', python_callable=evaluate_model, dag=dag)

# 순서 정의
t1 >> t2 >> t3 >> t4 >> t5
# Out:
# C:\Users\campus4D044\anaconda3\Lib\site-packages\airflow\__init__.py:45: RuntimeWarning: Airflow currently can be run on POSIX-compliant Operating Systems. For development, it is regularly tested on fairly modern Linux Distros and recent versions of macOS. On Windows you can run it via WSL2 (Windows Subsystem for Linux 2) or via Linux Containers. The work to add Windows support is tracked via https://github.com/apache/airflow/issues/10388, but it is not a high priority.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from airflow import DAG
#       2 from airflow.operators.python_operator import PythonOperator
#       3 from datetime import datetime, timedelta
#
# File ~\anaconda3\Lib\site-packages\airflow\__init__.py:79
#      73 # Perform side-effects unless someone has explicitly opted out before import
# ...
